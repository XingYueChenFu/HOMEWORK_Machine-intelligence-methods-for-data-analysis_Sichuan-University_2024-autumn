# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io


A = io.imread('Lena.bmp')
A = A / 255
# io.imshow(A)
# plt.show()
# print(A.shape)
# Out:
# c:\software\develop\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# (512, 512)

# %% [markdown]
# ## PCA
#
# 保留25个特征

# %%
num_eigenvalue = 25

# 去中心化
# X = A - A.mean()
X = A

# 计算协方差矩阵
C = X.dot(X.T)

# 特征值分解，得到特征矩阵
C_vals, C_vecs = np.linalg.eig(C)
C_vals, C_vecs = C_vals.astype(np.float64), C_vecs.astype(np.float64)

# 选前num_eigenvalue个
P = C_vecs[:,0:num_eigenvalue] # (num_eigenvalue, 512)

# 得到压缩数据
Y = (P.T).dot(X) # (num_eigenvalue, 512)

# 还原
X_re = P.dot(Y)

# 可视化
io.imshow(X)
plt.show()

plt.clf()
io.imshow(X_re)
plt.show()
# Out:
# C:\Users\XYCF\AppData\Local\Temp\ipykernel_13200\945694763.py:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   C_vals, C_vecs = C_vals.astype(np.float64), C_vecs.astype(np.float64)
